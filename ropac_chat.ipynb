# %% [markdown]
# # RoPac — personal assistant
#
# Portable folder — copy anywhere, run **`./start.sh`**
#
# Memory: **`data/memory.json`** · Model: **`roPac`** (see `config.json`)
#
# **Remember command:** `remember this-> your fact here`

# %%
from assistant import chat, show_memory, add_facts, MEMORY_PATH

print(f"Memory: {MEMORY_PATH}")
show_memory()

# %%
history = []

reply, history = chat(
    "remember this-> I am building a Kotlin Compose app called ShopMate",
    history,
)
print(reply)

# %%
reply, history = chat("What app am I building?", history)
print(reply)

# %%
show_memory()
